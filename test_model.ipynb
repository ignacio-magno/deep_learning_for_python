# %%
import numpy as np
import tensorflow as tf
import cv2 as cv
from matplotlib import pyplot as plt

# %%
import seaborn as sns


def showMatriz(matriz):
    print(matriz.shape)
    sns.heatmap(matriz, cmap="YlGnBu")
    plt.show()

# %%
# charge model
model = tf.keras.models.load_model('model.h5')

# %%
img = tf.keras.preprocessing.image.load_img(
    'test2.png', target_size=(224, 224)
)

# show image with plt
plt.imshow(img)

# %%
    # take portion of image
img = cv.imread('test2.png')
img = img[0:150, 0:224]

# resize image to 224x224
img = cv.resize(img, (28, 28))

# shape (28,28,3) is 28 x 28 array and 3 for 3 channels (RGB)

print(img[27])
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]

# %%
# reshape image to 1 dimension
input_data = img.reshape(1, 784)
showMatriz(input_data)

# transform shape (150, 672) to (1, 784)
#input_data = input_data.reshape(-1, 784)

#print(input_data.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 2
#       1 # reshape image to 1 dimension
# ----> 2 input_data = img.reshape(1, 784)
#       3 showMatriz(input_data)
#
# ValueError: cannot reshape array of size 2352 into shape (1,784)

# %%
model(input_data)
