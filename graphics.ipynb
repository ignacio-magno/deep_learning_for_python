# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = np.loadtxt('celsius_a_fahrenheit.csv', delimiter=',', skiprows=1)

# graficar los datos
plt.scatter(data[:, 0], data[:, 1])
plt.xlabel('Celsius')
plt.ylabel('Fahrenheit')
plt.legend(['Datos'])
plt.show()

# %%
sl = pd.read_csv('celsius_a_fahrenheit.csv')
sl
# Out:
#     Celsius  Fahrenheit
# 0       -50       -58.0
# 1       -40       -40.0
# 2       -30       -22.0
# 3       -20        -4.0
# 4       -10        14.0
# 5        -9        15.8
# 6        -8        17.6
# 7        -7        19.4
# 8        -6        21.2
# 9        -5        23.0
# 10       -4        24.8
# 11       -3        26.6
# 12       -2        28.4
# 13       -1        30.2
# 14        0        32.0
# 15        1        33.8
# 16        2        35.6
# 17        3        37.4
# 18        4        39.2
# 19        5        41.0
# 20        6        42.8
# 21        7        44.6
# 22        8        46.4
# 23        9        48.2
# 24       10        50.0
# 25       20        68.0
# 26       30        86.0
# 27       40       104.0
# 28       50       122.0
# 29       60       140.0

# %%
# graficar los datos
sl.plot()
# Out:
# <Axes: >
